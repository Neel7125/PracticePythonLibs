# %% [markdown]
# # **Pandas**

# %% [markdown]
# ### Basic Exploration

# %%
import pandas as pd

# %%
presidents = pd.read_csv('us_presidents.csv')
presidents
# Out:
#     S.No.               start                 end               president  \
# 0       1      April 30, 1789       March 4, 1797       George Washington
# 1       2       March 4, 1797       March 4, 1801              John Adams
# 2       3       March 4, 1801       March 4, 1809        Thomas Jefferson
# 3       4       March 4, 1809       March 4, 1817           James Madison
# 4       5       March 4, 1817       March 4, 1825            James Monroe
# 5       6       March 4, 1825       March 4, 1829       John Quincy Adams
# 6       7       March 4, 1829       March 4, 1837          Andrew Jackson
# 7       8       March 4, 1837       March 4, 1841        Martin Van Buren
# 8       9       March 4, 1841       April 4, 1841  William Henry Harrison
# 9      10       April 4, 1841       March 4, 1845              John Tyler
# 10     11       March 4, 1845       March 4, 1849           James K. Polk
# 11     12       March 4, 1849        July 9, 1850          Zachary Taylor
# 12     13        July 9, 1850       March 4, 1853        Millard Fillmore
# 13     14       March 4, 1853       March 4, 1857         Franklin Pierce
# 14     15       March 4, 1857       March 4, 1861          James Buchanan
# 15     16       March 4, 1861      April 15, 1865         Abraham Lincoln
# 16     17      April 15, 1865       March 4, 1869          Andrew Johnson
# 17     18       March 4, 1869       March 4, 1877        Ulysses S. Grant
# 18     19       March 4, 1877       March 4, 1881     Rutherford B. Hayes
# 19     20       March 4, 1881  September 19, 1881       James A. Garfield
# 20     21  September 19, 1881       March 4, 1885       Chester A. Arthur
# 21     22       March 4, 1885       March 4, 1889        Grover Cleveland
# 22     23       March 4, 1889       March 4, 1893       Benjamin Harrison
# 23     24       March 4, 1893       March 4, 1897        Grover Cleveland
# 24     25       March 4, 1897           14-Sep-01        William McKinley
# 25     26           14-Sep-01            4-Mar-09      Theodore Roosevelt
# 26     27            4-Mar-09            4-Mar-13     William Howard Taft
# 27     28            4-Mar-13            4-Mar-21          Woodrow Wilson
# 28     29            4-Mar-21            2-Aug-23       Warren G. Harding
# 29     30            2-Aug-23            4-Mar-29         Calvin Coolidge
# 30     31            4-Mar-29            4-Mar-33          Herbert Hoover
# 31     32            4-Mar-33           20-Jan-41   Franklin D. Roosevelt
# 32     33           12-Apr-45           20-Jan-53         Harry S. Truman
# 33     34           20-Jan-53           20-Jan-61    Dwight D. Eisenhower
# 34     35           20-Jan-61           22-Nov-63         John F. Kennedy
# 35     36           22-Nov-63           20-Jan-69       Lyndon B. Johnson
# 36     37           20-Jan-69            9-Aug-74           Richard Nixon
# 37     38            9-Aug-74           20-Jan-77             Gerald Ford
# 38     39           20-Jan-77           20-Jan-81            Jimmy Carter
# 39     40           20-Jan-81           20-Jan-89           Ronald Reagan
# 40     41           20-Jan-89           20-Jan-93       George H. W. Bush
# 41     42           20-Jan-93           20-Jan-01            Bill Clinton
# 42     43           20-Jan-01           20-Jan-09          George W. Bush
# 43     44           20-Jan-09                 NaN            Barack Obama
# 44     45           20-Jan-17                  --            Donald Trump
#
#                                                 prior  \
# 0   Commander-in-Chief  of the  Continental Army  ...
# 1            1st  Vice President of the United States
# 2            2nd  Vice President of the United States
# 3   5th  United States Secretary of State   (1801–...
# 4   7th  United States Secretary of State   (1811–...
# 5   8th  United States Secretary of State   (1817–...
# 6   U.S. Senator   ( Class 2 )   from  Tennessee  ...
# 7            8th  Vice President of the United States
# 8    United States Minister to Colombia   (1828–1829)
# 9           10th  Vice President of the United States
# 10           9th  Governor of Tennessee   (1839–1841)
# 11  Major General  of the  1st Infantry Regiment  ...
# 12          12th  Vice President of the United States
# 13  Brigadier General  of the  9th Infantry   Unit...
# 14  United States Minister  to the   Court of St J...
# 15  U.S. Representative  for  Illinois' 7th Distri...
# 16          16th  Vice President of the United States
# 17  Commanding General  of the U.S. Army   ( 1864–...
# 18  29th & 32nd  Governor of Ohio   (1868–1872 & 1...
# 19  U.S. Representative  for  Ohio's 19th District...
# 20          20th  Vice President of the United States
# 21           28th  Governor of New York   (1883–1885)
# 22  U.S. Senator   ( Class 1 )   from  Indiana   (...
# 23  22nd  President of the United States   (1885–1...
# 24               39th  Governor of Ohio   (1892–1896)
# 25          25th  Vice President of the United States
# 26  42nd  United States Secretary of War   (1904–1...
# 27         34th  Governor of New Jersey   (1911–1913)
# 28  U.S. Senator   ( Class 3 )   from  Ohio   (191...
# 29          29th  Vice President of the United States
# 30  3rd  United States Secretary of Commerce   (19...
# 31         44th  Governor of New York   ( 1929–1932 )
# 32          34th  Vice President of the United States
# 33    Supreme Allied Commander Europe   ( 1949–1952 )
# 34  U.S. Senator   ( Class 1 )   from  Massachuset...
# 35          37th  Vice President of the United States
# 36  36th  Vice President of the United States   (1...
# 37          40th  Vice President of the United States
# 38            76th  Governor of Georgia   (1971–1975)
# 39       33rd  Governor of California   ( 1967–1975 )
# 40          43rd  Vice President of the United States
# 41  40th & 42nd  Governor of Arkansas   (1979–1981...
# 42            46th  Governor of Texas   ( 1995–2000 )
# 43  U.S. Senator   ( Class 3 )   from  Illinois   ...
# 44  Chairman of   The Trump Organization   ( 1971–...
#
#                                           party                    vice
# 0                            Nonpartisan   [13]              John Adams
# 1                                    Federalist        Thomas Jefferson
# 2                       Democratic-  Republican              Aaron Burr
# 3                       Democratic-  Republican          George Clinton
# 4                       Democratic-  Republican      Daniel D. Tompkins
# 5                       Democratic-  Republican         John C. Calhoun
# 6                                    Democratic         John C. Calhoun
# 7                                    Democratic  Richard Mentor Johnson
# 8                                          Whig              John Tyler
# 9   Whig   April 4, 1841  –  September 13, 1841           Office vacant
# 10                                   Democratic        George M. Dallas
# 11                                         Whig        Millard Fillmore
# 12                                         Whig           Office vacant
# 13                                   Democratic         William R. King
# 14                                   Democratic    John C. Breckinridge
# 15        Republican   ( National Union )   [i]         Hannibal Hamlin
# 16  National Union   [i]   ( Democratic )   [j]           Office vacant
# 17                                   Republican         Schuyler Colfax
# 18                                   Republican      William A. Wheeler
# 19                                   Republican       Chester A. Arthur
# 20                                   Republican           Office vacant
# 21                                   Democratic     Thomas A. Hendricks
# 22                                   Republican          Levi P. Morton
# 23                                   Democratic         Adlai Stevenson
# 24                                   Republican           Garret Hobart
# 25                                   Republican           Office vacant
# 26                                   Republican        James S. Sherman
# 27                                   Democratic      Thomas R. Marshall
# 28                                   Republican         Calvin Coolidge
# 29                                   Republican           Office vacant
# 30                                   Republican          Charles Curtis
# 31                                   Democratic       John Nance Garner
# 32                                   Democratic           Office vacant
# 33                                   Republican           Richard Nixon
# 34                                   Democratic       Lyndon B. Johnson
# 35                                   Democratic           Office vacant
# 36                                   Republican             Spiro Agnew
# 37                                   Republican           Office vacant
# 38                                   Democratic          Walter Mondale
# 39                                   Republican       George H. W. Bush
# 40                                   Republican              Dan Quayle
# 41                                   Democratic                 Al Gore
# 42                                   Republican             Dick Cheney
# 43                                   Democratic               Joe Biden
# 44                                   Republican              Mike Pence

# %%
# Load dataset
df = pd.read_csv('us_presidents.csv')

# Display frst 10 rows
print("First 10 rows:\n", df.head(10))

print('-'*50)

# Display last 10 rows
print("Last 10 rows:\n", df.tail(10))
# Out:
# First 10 rows:
#     S.No.           start            end               president  \
# 0      1  April 30, 1789  March 4, 1797       George Washington
# 1      2   March 4, 1797  March 4, 1801              John Adams
# 2      3   March 4, 1801  March 4, 1809        Thomas Jefferson
# 3      4   March 4, 1809  March 4, 1817           James Madison
# 4      5   March 4, 1817  March 4, 1825            James Monroe
# 5      6   March 4, 1825  March 4, 1829       John Quincy Adams
# 6      7   March 4, 1829  March 4, 1837          Andrew Jackson
# 7      8   March 4, 1837  March 4, 1841        Martin Van Buren
# 8      9   March 4, 1841  April 4, 1841  William Henry Harrison
# 9     10   April 4, 1841  March 4, 1845              John Tyler
#
#                                                prior  \
# 0  Commander-in-Chief  of the  Continental Army  ...
# 1           1st  Vice President of the United States
# 2           2nd  Vice President of the United States
# 3  5th  United States Secretary of State   (1801–...
# 4  7th  United States Secretary of State   (1811–...
# 5  8th  United States Secretary of State   (1817–...
# 6  U.S. Senator   ( Class 2 )   from  Tennessee  ...
# 7           8th  Vice President of the United States
# 8   United States Minister to Colombia   (1828–1829)
# 9          10th  Vice President of the United States
#
#                                          party                    vice
# 0                           Nonpartisan   [13]              John Adams
# 1                                   Federalist        Thomas Jefferson
# 2                      Democratic-  Republican              Aaron Burr
# 3                      Democratic-  Republican          George Clinton
# 4                      Democratic-  Republican      Daniel D. Tompkins
# 5                      Democratic-  Republican         John C. Calhoun
# 6                                   Democratic         John C. Calhoun
# 7                                   Democratic  Richard Mentor Johnson
# 8                                         Whig              John Tyler
# 9  Whig   April 4, 1841  –  September 13, 1841           Office vacant
# --------------------------------------------------
# Last 10 rows:
#      S.No.      start        end          president  \
# 35     36  22-Nov-63  20-Jan-69  Lyndon B. Johnson
# 36     37  20-Jan-69   9-Aug-74      Richard Nixon
# 37     38   9-Aug-74  20-Jan-77        Gerald Ford
# 38     39  20-Jan-77  20-Jan-81       Jimmy Carter
# 39     40  20-Jan-81  20-Jan-89      Ronald Reagan
# 40     41  20-Jan-89  20-Jan-93  George H. W. Bush
# 41     42  20-Jan-93  20-Jan-01       Bill Clinton
# 42     43  20-Jan-01  20-Jan-09     George W. Bush
# 43     44  20-Jan-09        NaN       Barack Obama
# 44     45  20-Jan-17         --       Donald Trump
#
#                                                 prior       party  \
# 35          37th  Vice President of the United States  Democratic
# 36  36th  Vice President of the United States   (1...  Republican
# 37          40th  Vice President of the United States  Republican
# 38            76th  Governor of Georgia   (1971–1975)  Democratic
# 39       33rd  Governor of California   ( 1967–1975 )  Republican
# 40          43rd  Vice President of the United States  Republican
# 41  40th & 42nd  Governor of Arkansas   (1979–1981...  Democratic
# 42            46th  Governor of Texas   ( 1995–2000 )  Republican
# 43  U.S. Senator   ( Class 3 )   from  Illinois   ...  Democratic
# 44  Chairman of   The Trump Organization   ( 1971–...  Republican
#
#                  vice
# 35      Office vacant
# 36        Spiro Agnew
# 37      Office vacant
# 38     Walter Mondale
# 39  George H. W. Bush
# 40         Dan Quayle
# 41            Al Gore
# 42        Dick Cheney
# 43          Joe Biden
# 44         Mike Pence

# %%
# Shape and column names

print("Shape of DataFrame:", df.shape)
print("Column Names:", df.columns.tolist())

print('-'*50)

# Data types
print("Data Types:\n", df.dtypes)
print('-'*50)
print("Data types:\n", df.info())
# Out:
# Shape of DataFrame: (45, 7)
# Column Names: ['S.No.', 'start', 'end', 'president', 'prior', 'party', 'vice']
# --------------------------------------------------
# Data Types:
#  S.No.         int64
# start        object
# end          object
# president    object
# prior        object
# party        object
# vice         object
# dtype: object
# --------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   S.No.      45 non-null     int64
#  1   start      45 non-null     object
#  2   end        44 non-null     object
#  3   president  45 non-null     object
#  4   prior      45 non-null     object
#  5   party      45 non-null     object
#  6   vice       45 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 2.6+ KB
# Data types:
#  None

# %%
# Missing values
print("Missing Values:\n", df.isnull().sum())
print('-'*50)

# Unique Values
print("Unique Values in Each Column:\n")
for col in df.columns:
    print(f"{col}: {df[col].nunique()} unique values")
# Out:
# Missing Values:
#  S.No.        0
# start        0
# end          1
# president    0
# prior        0
# party        0
# vice         0
# dtype: int64
# --------------------------------------------------
# Unique Values in Each Column:
#
# S.No.: 45 unique values
# start: 45 unique values
# end: 44 unique values
# president: 44 unique values
# prior: 45 unique values
# party: 9 unique values
# vice: 36 unique values

# %% [markdown]
# ### Data Selection & Filtering

# %%
# Select Single Column
print("Single Column (Name):\n")
print(df['president'].head(10))
# Out:
# Single Column (Name):
#
# 0         George Washington
# 1                John Adams
# 2          Thomas Jefferson
# 3             James Madison
# 4              James Monroe
# 5         John Quincy Adams
# 6            Andrew Jackson
# 7          Martin Van Buren
# 8    William Henry Harrison
# 9                John Tyler
# Name: president, dtype: object

# %%
# Select Multiple Columns

print("Multiple Columns (Name, Party):\n")
print(df[['president', 'party']].head(10))
# Out:
# Multiple Columns (Name, Party):
#
#                 president                                        party
# 0       George Washington                           Nonpartisan   [13]
# 1              John Adams                                   Federalist
# 2        Thomas Jefferson                      Democratic-  Republican
# 3           James Madison                      Democratic-  Republican
# 4            James Monroe                      Democratic-  Republican
# 5       John Quincy Adams                      Democratic-  Republican
# 6          Andrew Jackson                                   Democratic
# 7        Martin Van Buren                                   Democratic
# 8  William Henry Harrison                                         Whig
# 9              John Tyler  Whig   April 4, 1841  –  September 13, 1841

# %%
# Select row by index

print("First 10 Rows:\n")
print(df.iloc[0:10])
# Out:
# First 10 Rows:
#
#    S.No.           start            end               president  \
# 0      1  April 30, 1789  March 4, 1797       George Washington
# 1      2   March 4, 1797  March 4, 1801              John Adams
# 2      3   March 4, 1801  March 4, 1809        Thomas Jefferson
# 3      4   March 4, 1809  March 4, 1817           James Madison
# 4      5   March 4, 1817  March 4, 1825            James Monroe
# 5      6   March 4, 1825  March 4, 1829       John Quincy Adams
# 6      7   March 4, 1829  March 4, 1837          Andrew Jackson
# 7      8   March 4, 1837  March 4, 1841        Martin Van Buren
# 8      9   March 4, 1841  April 4, 1841  William Henry Harrison
# 9     10   April 4, 1841  March 4, 1845              John Tyler
#
#                                                prior  \
# 0  Commander-in-Chief  of the  Continental Army  ...
# 1           1st  Vice President of the United States
# 2           2nd  Vice President of the United States
# 3  5th  United States Secretary of State   (1801–...
# 4  7th  United States Secretary of State   (1811–...
# 5  8th  United States Secretary of State   (1817–...
# 6  U.S. Senator   ( Class 2 )   from  Tennessee  ...
# 7           8th  Vice President of the United States
# 8   United States Minister to Colombia   (1828–1829)
# 9          10th  Vice President of the United States
#
#                                          party                    vice
# 0                           Nonpartisan   [13]              John Adams
# 1                                   Federalist        Thomas Jefferson
# 2                      Democratic-  Republican              Aaron Burr
# 3                      Democratic-  Republican          George Clinton
# 4                      Democratic-  Republican      Daniel D. Tompkins
# 5                      Democratic-  Republican         John C. Calhoun
# 6                                   Democratic         John C. Calhoun
# 7                                   Democratic  Richard Mentor Johnson
# 8                                         Whig              John Tyler
# 9  Whig   April 4, 1841  –  September 13, 1841           Office vacant

# %%
# Select specific row and column

print("Row with index 0 and specific columns (Name, Party):\n")
print(df.loc[0,['president', 'party']])
# Out:
# Row with index 0 and specific columns (Name, Party):
#
# president     George Washington
# party        Nonpartisan   [13]
# Name: 0, dtype: object

# %%
# Conditional filtering

print("Presidents from the Republican Party:\n")
print(df[df['party'] == 'Republican'][['president']])
# Out:
# Presidents from the Republican Party:
#
#                president
# 17      Ulysses S. Grant
# 18   Rutherford B. Hayes
# 19     James A. Garfield
# 20     Chester A. Arthur
# 22     Benjamin Harrison
# 24      William McKinley
# 25    Theodore Roosevelt
# 26   William Howard Taft
# 28     Warren G. Harding
# 29       Calvin Coolidge
# 30        Herbert Hoover
# 33  Dwight D. Eisenhower
# 36         Richard Nixon
# 37           Gerald Ford
# 39         Ronald Reagan
# 40     George H. W. Bush
# 42        George W. Bush
# 44          Donald Trump

# %%
# Multiple conditions

print("presidents from the Republican Party before 1850:\n")
print(df[(df['party'] == 'Republican') & (df['start'] <= 'July 9, 1850')][['president']])
# Out:
# presidents from the Republican Party before 1850:
#
#                president
# 25    Theodore Roosevelt
# 26   William Howard Taft
# 28     Warren G. Harding
# 29       Calvin Coolidge
# 30        Herbert Hoover
# 33  Dwight D. Eisenhower
# 36         Richard Nixon
# 37           Gerald Ford
# 39         Ronald Reagan
# 40     George H. W. Bush
# 42        George W. Bush
# 44          Donald Trump

# %%
# OR condition

print("presidents from the Republican or Democratic Party:\n")
print(df[(df['party'] == 'Republican') | (df['party'] == 'Democratic')] [['president']])
# Out:
# presidents from the Republican or Democratic Party:
#
#                 president
# 6          Andrew Jackson
# 7        Martin Van Buren
# 10          James K. Polk
# 13        Franklin Pierce
# 14         James Buchanan
# 17       Ulysses S. Grant
# 18    Rutherford B. Hayes
# 19      James A. Garfield
# 20      Chester A. Arthur
# 21       Grover Cleveland
# 22      Benjamin Harrison
# 23       Grover Cleveland
# 24       William McKinley
# 25     Theodore Roosevelt
# 26    William Howard Taft
# 27         Woodrow Wilson
# 28      Warren G. Harding
# 29        Calvin Coolidge
# 30         Herbert Hoover
# 31  Franklin D. Roosevelt
# 32        Harry S. Truman
# 33   Dwight D. Eisenhower
# 34        John F. Kennedy
# 35      Lyndon B. Johnson
# 36          Richard Nixon
# 37            Gerald Ford
# 38           Jimmy Carter
# 39          Ronald Reagan
# 40      George H. W. Bush
# 41           Bill Clinton
# 42         George W. Bush
# 43           Barack Obama
# 44           Donald Trump

# %% [markdown]
# ### Data Cleaning

# %%
# Drop columns

if "Wife" in df.columns:
    df_cleaned = df.drop(columns=['Wife'])
    print("\n-------Dropped 'Wife' Column-------\n", df_cleaned.head(10))
else:
    print("\n'Wife' column not found in the Dataset.")
# Out:
# 'Wife' column not found in the Dataset.

# %%
# Fill missing values

if "end" in df.columns:
    df["end"].fillna("Present", inplace=True)
# Out:
# C:\Users\neelp\AppData\Local\Temp\ipykernel_26016\202257069.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["end"].fillna("Present", inplace=True)

# %%
# Convert date columns to datetime

for col in ['start', 'end']:
    if col in df.columns:
        df[col] = pd.to_datetime(df[col], errors='coerce')

print("Converted DateTime\n")
print(df[['president', 'start', 'end']].head(50))
# Out:
# Converted DateTime
#
#                  president      start        end
# 0        George Washington 1789-04-30 1797-03-04
# 1               John Adams 1797-03-04 1801-03-04
# 2         Thomas Jefferson 1801-03-04 1809-03-04
# 3            James Madison 1809-03-04 1817-03-04
# 4             James Monroe 1817-03-04 1825-03-04
# 5        John Quincy Adams 1825-03-04 1829-03-04
# 6           Andrew Jackson 1829-03-04 1837-03-04
# 7         Martin Van Buren 1837-03-04 1841-03-04
# 8   William Henry Harrison 1841-03-04 1841-04-04
# 9               John Tyler 1841-04-04 1845-03-04
# 10           James K. Polk 1845-03-04 1849-03-04
# 11          Zachary Taylor 1849-03-04 1850-07-09
# 12        Millard Fillmore 1850-07-09 1853-03-04
# 13         Franklin Pierce 1853-03-04 1857-03-04
# 14          James Buchanan 1857-03-04 1861-03-04
# 15         Abraham Lincoln 1861-03-04 1865-04-15
# 16          Andrew Johnson 1865-04-15 1869-03-04
# 17        Ulysses S. Grant 1869-03-04 1877-03-04
# 18     Rutherford B. Hayes 1877-03-04 1881-03-04
# 19       James A. Garfield 1881-03-04 1881-09-19
# 20       Chester A. Arthur 1881-09-19 1885-03-04
# 21        Grover Cleveland 1885-03-04 1889-03-04
# 22       Benjamin Harrison 1889-03-04 1893-03-04
# 23        Grover Cleveland 1893-03-04 1897-03-04
# 24        William McKinley 1897-03-04        NaT
# 25      Theodore Roosevelt        NaT        NaT
# 26     William Howard Taft        NaT        NaT
# 27          Woodrow Wilson        NaT        NaT
# 28       Warren G. Harding        NaT        NaT
# 29         Calvin Coolidge        NaT        NaT
# 30          Herbert Hoover        NaT        NaT
# 31   Franklin D. Roosevelt        NaT        NaT
# 32         Harry S. Truman        NaT        NaT
# 33    Dwight D. Eisenhower        NaT        NaT
# 34         John F. Kennedy        NaT        NaT
# 35       Lyndon B. Johnson        NaT        NaT
# 36           Richard Nixon        NaT        NaT
# 37             Gerald Ford        NaT        NaT
# 38            Jimmy Carter        NaT        NaT
# 39           Ronald Reagan        NaT        NaT
# 40       George H. W. Bush        NaT        NaT
# 41            Bill Clinton        NaT        NaT
# 42          George W. Bush        NaT        NaT
# 43            Barack Obama        NaT        NaT
# 44            Donald Trump        NaT        NaT

# %%
# Create new column: presidency duration (in days)

if 'start' in df.columns and 'end' in df.columns:
    df['duration_days'] = (df['end'] - df['start']).dt.days

print("Duration :\n")
print(df[['president', 'start', 'end', 'duration_days']])
# Out:
# Duration :
#
#                  president      start        end  duration_days
# 0        George Washington 1789-04-30 1797-03-04         2865.0
# 1               John Adams 1797-03-04 1801-03-04         1460.0
# 2         Thomas Jefferson 1801-03-04 1809-03-04         2922.0
# 3            James Madison 1809-03-04 1817-03-04         2922.0
# 4             James Monroe 1817-03-04 1825-03-04         2922.0
# 5        John Quincy Adams 1825-03-04 1829-03-04         1461.0
# 6           Andrew Jackson 1829-03-04 1837-03-04         2922.0
# 7         Martin Van Buren 1837-03-04 1841-03-04         1461.0
# 8   William Henry Harrison 1841-03-04 1841-04-04           31.0
# 9               John Tyler 1841-04-04 1845-03-04         1430.0
# 10           James K. Polk 1845-03-04 1849-03-04         1461.0
# 11          Zachary Taylor 1849-03-04 1850-07-09          492.0
# 12        Millard Fillmore 1850-07-09 1853-03-04          969.0
# 13         Franklin Pierce 1853-03-04 1857-03-04         1461.0
# 14          James Buchanan 1857-03-04 1861-03-04         1461.0
# 15         Abraham Lincoln 1861-03-04 1865-04-15         1503.0
# 16          Andrew Johnson 1865-04-15 1869-03-04         1419.0
# 17        Ulysses S. Grant 1869-03-04 1877-03-04         2922.0
# 18     Rutherford B. Hayes 1877-03-04 1881-03-04         1461.0
# 19       James A. Garfield 1881-03-04 1881-09-19          199.0
# 20       Chester A. Arthur 1881-09-19 1885-03-04         1262.0
# 21        Grover Cleveland 1885-03-04 1889-03-04         1461.0
# 22       Benjamin Harrison 1889-03-04 1893-03-04         1461.0
# 23        Grover Cleveland 1893-03-04 1897-03-04         1461.0
# 24        William McKinley 1897-03-04        NaT            NaN
# 25      Theodore Roosevelt        NaT        NaT            NaN
# 26     William Howard Taft        NaT        NaT            NaN
# 27          Woodrow Wilson        NaT        NaT            NaN
# 28       Warren G. Harding        NaT        NaT            NaN
# 29         Calvin Coolidge        NaT        NaT            NaN
# 30          Herbert Hoover        NaT        NaT            NaN
# 31   Franklin D. Roosevelt        NaT        NaT            NaN
# 32         Harry S. Truman        NaT        NaT            NaN
# 33    Dwight D. Eisenhower        NaT        NaT            NaN
# 34         John F. Kennedy        NaT        NaT            NaN
# 35       Lyndon B. Johnson        NaT        NaT            NaN
# 36           Richard Nixon        NaT        NaT            NaN
# 37             Gerald Ford        NaT        NaT            NaN
# 38            Jimmy Carter        NaT        NaT            NaN
# 39           Ronald Reagan        NaT        NaT            NaN
# 40       George H. W. Bush        NaT        NaT            NaN
# 41            Bill Clinton        NaT        NaT            NaN
# 42          George W. Bush        NaT        NaT            NaN
# 43            Barack Obama        NaT        NaT            NaN
# 44            Donald Trump        NaT        NaT            NaN

# %%
# Save cleaned dataset

df.to_csv('us_presidents_cleaned.csv', index=False)
print("✅ Cleaned dataset saved to 'us_presidents_cleaned.csv'")
# Out:
# ✅ Cleaned dataset saved to 'us_presidents_cleaned.csv'
